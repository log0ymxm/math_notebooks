# %%
import networkx as nx
# %matplotlib inline

# %%
g = nx.hypercube_graph(2)

# %%
len(g.edges())
# Out:
# 4

# %%
[len(nx.hypercube_graph(n).edges())/2 for n in range(10)]
# Out:
# [0.0, 0.5, 2.0, 6.0, 16.0, 40.0, 96.0, 224.0, 512.0, 1152.0]

# %%
nx.clique(nx.hypercube_graph(3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-dd5e3e0aa4a9> in <module>()
# ----> 1 nx.clique(nx.hypercube_graph(3))
#
# TypeError: 'module' object is not callable

# %%
2**4
# Out:
# 16

# %%
nx.draw(nx.hypercube_graph(4))
